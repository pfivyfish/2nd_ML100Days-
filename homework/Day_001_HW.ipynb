# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(A, B):
    """
    請完成這個 Function 後往下執行
    """
    mean = np.mean((A - B)**2)
    return mean

def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 238.715
# The Mean absolute error is 12.494

# %%
"""
HW1
https://www.kaggle.com/iarunava/cell-images-for-detecting-malaria
Malaria is one of the diseases that still need to be dealing with nowadays.
The dataset on Kaggle is from the official website of NIH, as shown in the following url:
https://ceb.nlm.nih.gov/repositories/malaria-datasets/
The dataset was collected from 150 infected patients and 50 healthy patients at Chittagong Medical College Hospital, Bangladesh.
Then an expert annotated the dataset.
All data are images of slides.
The designed algorithm should classify the images into two catagories: infected or healthy.
"""

# %%
"""
HW2
1.降低等待載客的時間長度以及增加每單程能獲得的收費
假設計程車在特定區域中移動直到找到客人前往特定地點或是遇到路邊攔車
2.資料可以從計程車的計費表獲得，包括客人開始搭車的時刻、到達目的地的時刻、路程長度、所需的時間長度以及總收費
若有APP，還可以記錄上車地點和目的地位置
3.資料型態皆為數字，包括時間、長度、金額和GPS(如果有的話)
4.從A點上車的客人收費是否會超過特定值
"""
